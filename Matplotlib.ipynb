# %%
# Out:
# Package                   Version
# ------------------------- ---------------
# altair                    5.5.0
# annotated-types           0.7.0
# anyio                     4.9.0
# argon2-cffi               25.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 3.0.0
# async-lru                 2.0.5
# attrs                     25.3.0
# audioop-lts               0.2.2
# babel                     2.17.0
# beautifulsoup4            4.13.4
# bleach                    6.2.0
# blinker                   1.9.0
# cachetools                5.5.2
# certifi                   2025.7.14
# cffi                      1.17.1
# charset-normalizer        3.4.2
# click                     8.2.1
# cohere                    5.17.0
# colorama                  0.4.6
# comm                      0.2.2
# comtypes                  1.4.12
# contourpy                 1.3.2
# cycler                    0.12.1
# debugpy                   1.8.15
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x_data = np.random.random(50) * 100
y_data = np.random.random(50)* 100

plt.bar(x_data,y_data)
plt.show()

# %%
x_data = np.random.random(50) * 100
y_data = np.random.random(50)* 100

plt.plot(x_data,y_data)
plt.show()

# %%
x_data = np.random.random(50) * 100
y_data = np.random.random(50)* 100

plt.scatter(x_data,y_data,c="#000", marker="*")
plt.show()

# %%
x_data = [2006 + x for x in range(16)]
y_data = [80,82,83,87,80,85,80,82,83,87,80,85,80,82,83,87]

plt.plot(x_data,y_data)
plt.show()

# %%
x_data = [2006 + x for x in range(16)]
y_data = [80,82,83,87,80,85,80,82,83,87,80,85,80,82,83,87]

plt.scatter(x_data,y_data)
plt.show()

# %%
x_data = [2006 + x for x in range(16)]
y_data = [80,82,83,87,80,85,80,82,83,87,80,85,80,82,83,87]

plt.plot(x_data,y_data, c="g",lw=3, linestyle="--")
plt.show()

# %%
langs = ["Python", "java","C","C++","GO"]

# %%
from matplotlib import style
votes=[50,24,14,6,17]
explodes =[0,0,0,0.2,0]
style.use("dark_background")

# %%
plt.pie(votes,labels= langs,explode = explodes, autopct ="%.2f%%" )
plt.show()

# %%
years =[2014,2015,2016,2017,2018,2019,2020,2021]
Income = [55,56,62,61,72,72,73,75]
Income_ticks = list(range(50,81,2))

# %%
plt.plot(years,Income)
plt.title("income of john")
plt.show()

# %%
stock_a=[100,110,164,137,139,130]
stock_b=[103,140,169,180,138,148]
stock_c=[103,184,189,134,197,146]
plt.plot(stock_a, label="Startup1")
plt.plot(stock_b,label="Startup2")
plt.plot(stock_c, label="Startup3")
plt.legend(loc="lower center")
plt.show()
